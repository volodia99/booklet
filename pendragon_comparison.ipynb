# %%
# %run -i /home/gwf/Desktop/dustyfargoadsg_gaylor/python/python_backup/3dclassplanet.py
# Out:
# /home/gwf/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1075: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# /home/gwf/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
